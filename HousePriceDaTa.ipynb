# %%
dataset_url = "https://www.kaggle.com/datasets/yasserh/housing-prices-dataset"

# %%
# %pip install seaborn

import numpy as np 
import pandas as pd 

# matplotlib and seaborn for visualization 
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    -------- ------------------------------ 61.4/294.9 kB 469.7 kB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv("Housing.csv")

# %%
# %pip install jinja2
# Out:
# ...
#   Obtaining dependency information for jinja2 from https://files.pythonhosted.org/packages/62/a1/3d680cbfd5f4b8f15abc1d571870c5fc3e594bb582bc3b64ea099db13e56/jinja2-3.1.6-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/83/8a/4414c03d3f891739326e1783338e48fb49781cc915b2e0ee052aa490d586/markupsafe-3.0.3-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/134.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/134.9 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/134.9 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/134.9 kB 325.1 kB/s eta 0:00:01
#    -------------------------------------- 134.9/134.9 kB 997.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# ...

# %%
df .head(5).style.background_gradient(cmap="jinja2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style.py:374, in Styler._repr_html_(self)
#     369 """
#     370 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     371 default if an object is returned at the end of a cell.
#     372 """
#     373 if get_option("styler.render.repr") == "html":
# --> 374     return self.to_html()
#     375 return None
#
# ...
